# %% [markdown]
# # Plotting Techniques

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from math import *
plt.figure(figsize=(20,20))
x = np.linspace(0,1,100)
x2 = np.linspace(0,0.5,100)
y1 = np.power(x,2)-np.power(x,3)
y2 = np.power(x2,2)+np.power(x2,3)
plt.plot(x,y1,label='line1')
plt.plot(x2,y2,label='line2')
plt.legend()
plt.show()

# %%
import mysignals as sig

# %%
style.use('ggplot')
plt.figure(figsize=(10,10))
f,plt_arr = plt.subplots(3,sharex=True)
f.suptitle('Multiplot')

plt_arr[0].plot(sig.InputSignal_1kHz_15kHz,color='magenta')
plt_arr[0].set_title('Sub plot 1')
plt_arr[1].plot(sig.InputSignal_1kHz_15kHz,color='yellow')
plt_arr[1].set_title('Sub plot 2')
plt_arr[2].plot(sig.InputSignal_1kHz_15kHz,color='red')
plt_arr[2].set_title('Sub plot 2')
# Out:
# Text(0.5, 1.0, 'Sub plot 2')

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

t = np.linspace(0,1.0,2001)

sig_5Hz = np.sin(2*np.pi*5*t)
sig_250Hz = np.sin(2*np.pi*50*t)
sig_5Hz_250Hz = sig_5Hz + sig_250Hz

f,plt_arr = plt.subplots(3,sharex=True)
f.suptitle('Signal Generation')

plt_arr[0].plot(sig_5Hz,color='magenta')
plt_arr[0].set_title('5Hz Signal')

plt_arr[1].plot(sig_250Hz,color='green')
plt_arr[1].set_title('250Hz Signal')

plt_arr[2].plot(sig_5Hz_250Hz,color='red')
plt_arr[2].set_title('5+250Hz Signal')
# Out:
# Text(0.5, 1.0, '5+250Hz Signal')
